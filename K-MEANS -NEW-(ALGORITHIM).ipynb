# %%
import cv2
# Out:
# C:\anaconda_new\lib\site-packages\numpy\core\__init__.py:29: UserWarning: loaded more than 1 DLL from .libs:
# C:\anaconda_new\lib\site-packages\numpy\.libs\libopenblas.IPBC74C7KURV7CB2PKT5Z5FNR3SIBV4J.gfortran-win_amd64.dll
# C:\anaconda_new\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
im_1=cv2.imread("C:/Users/admin pc/Desktop/lena_256.jpg",0)

# %%
im_1
# Out:
# array([[139, 134, 133, ..., 144, 150, 123],
#        [138, 135, 133, ..., 151, 156, 127],
#        [135, 135, 133, ..., 118, 106,  78],
#        ...,
#        [ 25,  26,  27, ...,  54,  62,  63],
#        [ 21,  24,  27, ...,  61,  67,  66],
#        [ 20,  25,  28, ...,  69,  72,  70]], dtype=uint8)

# %%
im_1.shape
# Out:
# (256, 256)

# %%
cv2.imshow("im_1",im_1)

# %%
#cv2.waitKey(0)

# %%
im_2=im_1.flatten()

# %%
im_2
# Out:
# array([139, 134, 133, ...,  69,  72,  70], dtype=uint8)

# %%
data=list(im_2)

# %%
data
# Out:
# [139,
#  134,
#  133,
#  136,
#  137,
#  135,
#  133,
#  134,
#  131,
#  136,
#  132,
#  129,
#  134,
#  130,
#  123,
#  128,
#  127,
#  131,
#  136,
#  139,
#  141,
#  144,
#  149,
#  153,
#  147,
#  145,
#  150,
#  132,
#  123,
#  123,
#  98,
#  79,
#  66,
#  60,
#  57,
#  69,
#  68,
#  74,
#  72,
#  73,
#  78,
#  72,
#  74,
#  78,
#  74,
#  73,
#  77,
#  76,
#  77,
#  78,
#  75,
#  74,
#  78,
#  81,
#  83,
#  86,
#  82,
#  90,
#  94,
#  89,
#  94,
#  95,
#  90,
#  98,
#  100,
#  97,
#  95,
#  98,
#  103,
#  104,
#  101,
#  97,
#  97,
#  97,
#  98,
#  99,
#  98,
#  98,
#  102,
#  106,
#  97,
#  100,
#  102,
#  102,
#  101,
#  101,
#  101,
#  100,
#  101,
#  102,
#  100,
#  99,
#  100,
#  104,
#  103,
#  100,
#  103,
#  103,
#  104,
#  104,
#  104,
#  103,
#  103,
#  103,
#  105,
#  104,
#  102,
#  100,
#  100,
#  101,
#  100,
#  98,
#  100,
#  103,
#  104,
#  102,
#  100,
#  100,
#  99,
#  98,
#  104,
#  102,
#  102,
#  105,
#  104,
#  100,
#  98,
#  98,
#  111,
#  104,
#  97,
# ...

# %%
im_2=im_1.reshape((-1,1))

# %%
im_2
# Out:
# array([[139],
#        [134],
#        [133],
#        ...,
#        [ 69],
#        [ 72],
#        [ 70]], dtype=uint8)

# %%
im_3=np.float32(im_2)

# %%
im_3
# Out:
# array([[139.],
#        [134.],
#        [133.],
#        ...,
#        [ 69.],
#        [ 72.],
#        [ 70.]], dtype=float32)

# %%
criteria=(cv2.TERM_CRITERIA_EPS+cv2.TERM_CRITERIA_MAX_ITER,100,0.85)

# %%
k=2
retval, labels, centers = cv2.kmeans(im_3, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)

# %%
centers
# Out:
# array([[144.90062 ],
#        [ 57.543022]], dtype=float32)

# %%
labels
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [1],
#        [1]], dtype=int32)

# %%
retval
# Out:
# 56929663.073179446

# %%
centers_1=np.uint8(centers)

# %%
centers_1
# Out:
# array([[144],
#        [ 57]], dtype=uint8)

# %%
im_4=centers_1[labels.flatten()]

# %%
im_5=im_4.reshape((im_1.shape))

# %%
im_5
# Out:
# array([[144, 144, 144, ..., 144, 144, 144],
#        [144, 144, 144, ..., 144, 144, 144],
#        [144, 144, 144, ..., 144, 144,  57],
#        ...,
#        [ 57,  57,  57, ...,  57,  57,  57],
#        [ 57,  57,  57, ...,  57,  57,  57],
#        [ 57,  57,  57, ...,  57,  57,  57]], dtype=uint8)

# %%
plt.imshow(im_5)
